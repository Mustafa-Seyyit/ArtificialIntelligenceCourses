# %%
toplam = 0
while True:
    sayi = int(input("bir sayi giriniz çıkmak için -1 giriniz."))
    if sayi == -1:
        break
    toplam += sayi
print(f"girilen sayıların toplamı: {toplam}")
# Out:
# girilen sayıların toplamı: 13
