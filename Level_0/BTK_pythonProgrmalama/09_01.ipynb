# %%
sayilar = [10, 5, 8, 9, 23, 55]

print(sayilar[0])
print(sayilar[3])
# Out:
# 10
# 9

# %%
isimler = ["mustafa", "fatmanur", "seyyit", "dogan"]
print(isimler[-1])
print(isimler[-2])
# Out:
# dogan
# seyyit

# %%
karisik = ["mustafa", 8, True, 3.14, False]
print(karisik)
# Out:
# ['mustafa', 8, True, 3.14, False]

# %%
sayilar.append(5)
print(sayilar)
# Out:
# [10, 5, 8, 9, 23, 55, 5]

# %%
sayilar.insert(1, 28)
print(sayilar)
# Out:
# [10, 28, 5, 8, 9, 23, 55, 5]

# %%
sayilar
# Out:
# [10, 28, 5, 8, 9, 23, 55, 5]

# %%
sayilar.pop(0)
print(sayilar)
# Out:
# [28, 5, 8, 9, 23, 55, 5]

# %%
sayilar
# Out:
# [28, 5, 8, 9, 23, 55, 5]

# %%
sayilar.sort()
print(sayilar)
# Out:
# [5, 5, 8, 9, 23, 28, 55]

# %%
sayilar.reverse()
print(sayilar)
# Out:
# [55, 28, 23, 9, 8, 5, 5]

# %%
len(sayilar)
# Out:
# 7

# %%
sayilar.append(16)
print(sayilar)
# Out:
# [55, 28, 23, 9, 8, 5, 5, 16]

# %%
sayilar = sorted(sayilar)
print(sayilar)
# Out:
# [5, 5, 8, 9, 16, 23, 28, 55]

# %%
sayilar
# Out:
# [5, 5, 8, 9, 16, 23, 28, 55]

# %%
sayilar.remove(16)
print(sayilar)
# Out:
# [5, 5, 8, 9, 23, 28, 55]

# %%
sayilar.pop(-2)
print(sayilar)
# Out:
# [5, 5, 8, 9, 23, 55]
