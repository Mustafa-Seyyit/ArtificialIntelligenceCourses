# %%
for sayi in range(1, 11):
    if sayi %2 ==1:
        continue
    print(sayi)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
limit = int(input("limit değerini giriniz"))

for sayi in range(1, limit+1):
    if sayi % 2 == 0:
        continue
    print(sayi)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13
# 15
# 17
