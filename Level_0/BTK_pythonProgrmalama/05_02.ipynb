# %%
pi = 3.14
isim = "Mustafa"
kontrol = True
tamSayi = 8

print(pi)
print(isim)
print(kontrol)
print(tamSayi)
# Out:
# 3.14
# Mustafa
# True
# 8

# %%
print(type(pi))
print(type(isim))
print(type(kontrol))
print(type(tamSayi))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'int'>
