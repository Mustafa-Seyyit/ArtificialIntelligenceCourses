# %% [markdown]
# # En Büyük Sayiyi Bulmak

# %%
sayilar = [12, 5, 99, 28, 12]

buyuk = sayilar[0]

for i in range(len(sayilar)):
    if sayilar[i] > buyuk:
        buyuk = sayilar[i]

print(f"en büyük sayi: {buyuk}")
# Out:
# en büyük sayi: 99

# %%
min(sayilar)
# Out:
# 5

# %%
max(sayilar)
# Out:
# 99

# %%
sum(sayilar)
# Out:
# 156
