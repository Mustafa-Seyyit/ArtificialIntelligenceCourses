# %%
def binary_search(arr, target, left, right):
    if left > right:
        return -1

    mid =(left+ right)//2

    if arr[mid] == target:
        return mid
    elif arr[mid]>target:
        return binary_search(arr, target, left, mid-1)
    else:
        return binary_search(arr, target, mid+1, right)

import random
import sorting_algorithms

numbers = [random.randint(1,100) for i in range(10)]
print(numbers)

numbers = sorting_algorithms.insertion_sort(numbers)
print(numbers)

target = 55
index = binary_search(numbers, 55, 0, len(numbers)-1)
if index != -1:
    print("hedef bulundu! indeks: ", index)
else:
    print("hedef bulunamadı.")
# Out:
# [80, 71, 77, 54, 86, 26, 93, 73, 55, 58]
# [26, 54, 55, 58, 71, 73, 77, 80, 86, 93]
# hedef bulundu! indeks:  2
