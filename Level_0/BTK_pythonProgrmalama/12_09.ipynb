# %% [markdown]
# # Sezar Şifreleme

# %%
text = input("lütfen şifrelenecek metini giriniz")
shift = int(input("kaç harf kaydırılsın? (örn: 3)"))

text = text.upper()
encrypted_text = ""

for char in text:
    if char.isalpha():
        new_char_code = ord(char) +shift
        if new_char_code > ord('Z'):
            new_char_code = ord('A') + (new_char_code-ord('Z') -1)
        encrypted_text += chr(new_char_code)
    else:
        encrypted_text  += char

print(f"girilen ifade: {text}")
print(f"şifrelenmiş metin: {encrypted_text}")
# Out:
# girilen ifade: MUSTAFA 82 SEYIT
# şifrelenmiş metin: PXVWDID 82 VHBLW
