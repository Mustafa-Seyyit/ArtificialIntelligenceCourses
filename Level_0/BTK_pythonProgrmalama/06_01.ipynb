# %%
sayi = int(input("bir sayi giriniz:"))
if sayi > 5:
    print(f"{sayi} > 5")
print("program bitti")
# Out:
# 8 > 5
# program bitti

# %%
x = float(input("lütfen bir sayi giriniz:"))

if x %2 == 0:
    print(f"girilen sayi: {x}, çift sayidir")
else:
    print(f"girilen sayi: {x}, negatifdir")
# Out:
# girilen sayi: 2.0, çift sayidir

# %%
sayi = float(input("lütfen bir sayi giriniz:"))

if x > 0:
    print("girilen sayi: {sayi:.2f}, pozitifdir")
elif x < 0:
    print("girilen sayi: {sayi:.2f}, negatifdir")
else:
    print("girilen sayi: {sayi:.2f}, sıfırdır")
# Out:
# girilen sayi: {sayi:.2f}, pozitifdir

# %%
dogru_kullanici = "admin"
dogru_sifre = "1234"

# girisleri al
kullanici = input("Kullanici adiniz: ")
sifre = input("Şifreniz: ")

if kullanici==dogru_kullanici:
    if sifre == dogru_sifre:
        print("Giriş başarılı hoş geldiniz.")
    else:
        print("Hatalı parola, lütfen şifrenizi kontrol ediniz.")
else:
    print(f"Böyle bir kullanıcı bulunamadı:{kullanici}")
# Out:
# Giriş başarılı hoş geldiniz.
