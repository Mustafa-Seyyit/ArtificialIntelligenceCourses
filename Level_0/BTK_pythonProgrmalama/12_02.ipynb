# %%
name = input("Adınızı giriniz: ").lower()
print(name)
print(type(name))
# Out:
# mustafa
# <class 'str'>

# %%
word1= "Merhaba"

# değer - referans
word2 = word1 #yeni bir nesne oluşturuluyor | yeni bir referans

print(word1, word2)
word1 = "Hoşçakal"
print(word1, word2)
# Out:
# Merhaba Merhaba
# Hoşçakal Merhaba

# %%
l1 = [1,2,3]
l2 = l1 #value / ref | yeni nesne üretilmedi
print(l1, l2)

l1.append(10)
l2.remove(1)
print(l1, l2)
# Out:
# [1, 2, 3] [1, 2, 3]
# [2, 3, 10] [2, 3, 10]

# %%
name = "Mustafa"
print(name[0])
print(name[-1])
print(name[-2])
print(name[3])
# Out:
# M
# a
# f
# t

# %%
name[0] = "m"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 name[0] = "m"
#
# TypeError: 'str' object does not support item assignment

# %%
print(len(name))
# Out:
# 7

# %%
names = ["mustafa", "seyyit", "fatmanur", "doğan"]
for name in names:
    print("sıradaki kişi: ", name.upper())
# Out:
# sıradaki kişi:  MUSTAFA
# sıradaki kişi:  SEYYIT
# sıradaki kişi:  FATMANUR
# sıradaki kişi:  DOĞAN

# %%
#Dilimleme
sentence = "Programlama öğreniyorum"
print(sentence[0:7])
print(sentence[4:])
print(sentence[:5])
print(sentence[::2])
# Out:
# Program
# ramlama öğreniyorum
# Progr
# Pormaaörnyrm

# %%
print(name)
print(name[::-1])
# Out:
# doğan
# nağod

# %%
new_sentence = "Merhaba " + name[:2].title() + " Bey"
print(new_sentence)
# Out:
# Merhaba Do Bey

# %%
print(len(new_sentence))
print(new_sentence[15])
# Out:
# 14
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 print(len(new_sentence))
# ----> 2 print(new_sentence[15])
#
# IndexError: string index out of range
