# %%
message = "Merhaba Dünya!"
print(message)
print(type(message))
# Out:
# Merhaba Dünya!
# <class 'str'>

# %%
#Tırnak
name1 = 'Mustafa'
name2 =  'Seyyit'
print(name1, name2)
# Out:
# Mustafa Seyyit

# %%
sentence = "Mustafa dedi ki: 'Python öğreniyorum.'"
print(sentence)
# Out:
# Mustafa dedi ki: 'Python öğreniyorum.'

# %%
sentence = 'Mustafa dedi ki: \'Python öğreniyorum.\''
print(sentence)
# Out:
# Mustafa dedi ki: 'Python öğreniyorum.'

# %%
expression = """Bir hava güzel.
Dışarı çıkacağım.
Kahve içeceğim.
Arkadaşlarımla görüşüceğim.
Eve döneceğim.
"""
print(expression)
# Out:
# Bir hava güzel.
# Dışarı çıkacağım.
# Kahve içeceğim.
# Arkadaşlarımla görüşüceğim.
# Eve döneceğim.
