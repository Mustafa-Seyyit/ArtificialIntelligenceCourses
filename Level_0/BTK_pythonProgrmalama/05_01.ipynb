# %%
var1 = 5
var2 = 5.0
var3 = "5"
var4 = 5 == 5

print(var1)
print(var2)
print(var3)
print(var4)
# Out:
# 5
# 5.0
# 5
# True

# %%
print(type(var1))
print(type(var2))
print(type(var3))
print(type(var4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
var1*2
# Out:
# 10

# %%
var2*2
# Out:
# 10.0

# %%
var3*2
# Out:
# '55'

# %%
var4*2
# Out:
# 2
