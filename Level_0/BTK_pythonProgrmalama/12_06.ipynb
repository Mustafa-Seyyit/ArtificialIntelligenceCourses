# %% [markdown]
# # Anagram

# %%
word1 = "elma"
word2 = "amel"

if sorted(word1.lower()) == sorted(word2.lower()):
    print("bu iki kelime anagramdır.")
else:
    print("bu iki kelime agnagram değildir!")
# Out:
# bu iki kelime anagramdır.
